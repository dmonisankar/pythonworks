# %%
# !ls
# Out:
# geocoding_exercise.ipynb
# pandas_lab1.ipynb
# supermarkets-commas.txt
# supermarkets-commas_without_headers.txt
# supermarkets-semi-colons.txt
# supermarkets.csv
# supermarkets.json
# supermarkets.xlsx

# %%
import pandas as pd

# %%
df = pd.read_csv("supermarkets-commas.txt")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df = df.set_index('ID')
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_t = df.T
df_t
# Out:
# ID                     1               2                 3              4  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
#
# ID                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# State           California         CA 94114
# Country                USA              USA
# Name               Sanchez       Richvalley
# Employees               12               20

# %%
df_t['7'] = ["62, Purba Para, Purba Barsiha", "kolkata", "West Bengal 700063", "India", "Monisankar", "25" ]

# %%
df_t
# Out:
# ID                     1               2                 3              4  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
#
# ID                       5                6                              7
# Address    1056 Sanchez St  551 Alvarado St  62, Purba Para, Purba Barsiha
# City         San Francisco    San Francisco                        kolkata
# State           California         CA 94114             West Bengal 700063
# Country                USA              USA                          India
# Name               Sanchez       Richvalley                     Monisankar
# ...

# %%
df = df_t.T
df
# Out:
#                           Address           City               State Country  \
# ID
# 1                    3666 21st St  San Francisco            CA 94114     USA
# 2                  735 Dolores St  San Francisco            CA 94119     USA
# 3                     332 Hill St  San Francisco    California 94114     USA
# 4                    3995 23rd St  San Francisco            CA 94114     USA
# 5                 1056 Sanchez St  San Francisco          California     USA
# 6                 551 Alvarado St  San Francisco            CA 94114     USA
# 7   62, Purba Para, Purba Barsiha        kolkata  West Bengal 700063   India
#
#            Name Employees
# ID
# 1       Madeira         8
# 2   Bready Shop        15
# 3   Super River        25
# 4    Ben's Shop        10
# 5       Sanchez        12
# 6    Richvalley        20
# 7    Monisankar        25

# %%
import geopy

# %%
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
dir(geopy.geocoders)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'GeocoderNotFound',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'SERVICE_TO_GEOCODER',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'algolia',
#  'arcgis',
#  'azure',
#  'baidu',
#  'banfrance',
#  'base',
#  'bing',
#  'databc',
#  'geocodeearth',
#  'geocodefarm',
#  'geolake',
#  'geonames',
#  'get_geocoder_for_service',
#  'googlev3',
#  'here',
#  'ignfrance',
#  'mapbox',
#  'mapquest',
#  'maptiler',
#  'opencage',
#  'openmapquest',
#  'options',
#  'osm',
#  'pelias',
#  'photon',
# ...

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
n = nom.geocode("62, Purba Para, Purba Barisha, Kolkata, West Bengal, India 700063")

# %%
n.latitude, n.longitude,
# Out:
# (22.46928424646544, 88.31778879378498)
